# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls drive/MyDrive
# Out:
#  AI_SaaS_MVP_Roadmap_Notion.md			   Files
#  all_ans.gdoc					   FINAL450.xlsx
# ' ANN-Hyper Parameter Optimization.ipynb'	  'Final & second Project.gdoc'
#  BackPack_Ans.gdoc				   mohsin.pdf
#  certificate.pdf				   NSE-TATAGLOBAL.csv
#  Churn_Modelling.csv				  'phitron backup'
# 'Colab Notebooks'				   Photo
# 'Copy of c_programming.pdf'			  'professinal email.gdoc'
# 'Copy of Zapier: Gmail signature templates.gdoc'  'project update.gdoc'
#  Cv_mohsin.pdf					   tatatest.csv
# 'Dogs vs Cats(Upgrade).ipynb'			   xray_dataset.zip

# %%
df = pd.read_csv('drive/MyDrive/NSE-TATAGLOBAL.csv')
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
df.shape
# Out:
# (2035, 8)
